# %%
''' Seasonal Draught Prediction'''
# @author: Philine Bommer
# Date: 09.05.22
# Description: 1. Include Paulas Start Up Notebook
# 2. Baselines: GP, MLP, simple CNN (MobileNet2/EfficientNet -> small data, try augmentation)
# 3. Explainability: Shapley,LIME,ExplanationByExample
# Out:
# ' Seasonal Draught Prediction'

# %%
# DATA Packages:
import netCDF4 as nc
import xarray as xr
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr

# ML Libraries
import torchvision
import torch.optim as optim
import pytorch_lightning as pl
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader


our_seed = 1
pl.seed_everything(our_seed)
# Out:
# Global seed set to 1
# 1

# %% [markdown]
# ## Data loading and visualization

# %%
#download
# !curl https://zenodo.org/record/6532501/files/CESM_EA_SPI.nc?download=1 --output CESM_EA_SPI.nc

file_name = 'CESM_EA_SPI.nc'
ds = xr.open_dataset(file_name)
spi = ds['spi']
spi
# Out:
# <xarray.DataArray 'spi' (time: 21612, lat: 13, lon: 20)>
# [5619120 values with dtype=float64]
# Coordinates:
#   * time     (time) object '0400-01-16T12:00:00' ... '2200-12-16T12:00:00'
#   * lat      (lat) float64 3.298 4.241 5.183 6.126 ... 11.78 12.72 13.66 14.61
#   * lon      (lon) float64 23.75 25.0 26.25 27.5 28.75 ... 43.75 45.0 46.25 47.5
# Attributes:
#     title:          Standardized Precipitation Index
#     standard_name:  atmosphere_water__standardized_precipitation_wetness_index
#     long_name:      Standardized Precipitation Index
#     units:          unitless
#     valid_min:      -3.09
#     valid_max:      3.09
#     valid_range:    [-3.09  3.09]

# %%
#plot spatial spi distribution for random time
time = np.random.randint(spi.shape[0])
spi2d = spi.isel(time=time)
spi2d.plot()

# %%
#plot overall spi distribution
plt.hist(np.array(spi.mean(dim = ['lat','lon'])).flatten(), bins=100)
plt.title('SPI distribution')
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
def assemble_predictors_predictands(start_date, end_date, lead_time, dataset, num_input_time_steps, algo):
    '''
    Args
    ----
    start_date (str): The start date for extraction. Important, put the trailing 0 at the beginning of year for dates before 1000 (e.g., '0400')
    end_date (str): The end date for extraction
    lead_time (int): The number of months between the predictor/predictand
    dataset (str): Either 'CESM' or 'ECMWF'
    num_input_time_steps (int): The number of time steps to use for each predictor samples
    '''    
    file_name = {'CESM': 'CESM_EA_SPI.nc', 'ECMWF': 'ECMWF_EA_SPI.nc'}[dataset]
    ds = xr.open_dataset(file_name)
    if algo == 'Net':
        spis = ds['spi']
        spis = (spis - spis.mean(dim = 'time'))/spis.std(dim = 'time')
        print("Data standardized")
    else: 
        spis = ds['spi']
    spi = spis.sel(time=slice(start_date,end_date))
    num_samples=spi.shape[0]

    #Stack and remove nans
    spi = np.stack([spi.values[n-num_input_time_steps:n] for n in range(num_input_time_steps, num_samples+1)])
    num_samples = spi.shape[0]
    spi[np.isnan(spi)] = 0

    #make sure we have floats in there
    X = spi.astype(np.float32)

    # select Y
    if dataset == 'ECMWF':
        start_date_plus_lead = pd.to_datetime(start_date) + pd.DateOffset(months=lead_time+num_input_time_steps-1)
        end_date_plus_lead = pd.to_datetime(end_date) + pd.DateOffset(months=lead_time)

    elif dataset == 'CESM':
        t_start=datetime.datetime(int(start_date.split('-')[0]),int(start_date.split('-')[1]),int(start_date.split('-')[2]))
        t_end=datetime.datetime(int(end_date.split('-')[0]),int(end_date.split('-')[1]),int(end_date.split('-')[2]))
        start_date_plus_lead = t_start + relativedelta(months=lead_time+num_input_time_steps-1)
        end_date_plus_lead = t_end + relativedelta(months=lead_time)
        #target_start_date_with_2_month = start_date_plus_lead - relativedelta(months=2)
        if len(str(start_date_plus_lead.year))<4:
            start_date_plus_lead = '0'+start_date_plus_lead.strftime('%Y-%m-%d')
        elif len(str(start_date_plus_lead.year))==4:
            start_date_plus_lead = start_date_plus_lead.strftime('%Y-%m-%d')
        if len(str(end_date_plus_lead.year))<4:
            end_date_plus_lead = '0'+end_date_plus_lead.strftime('%Y-%m-%d')
        elif len(str(end_date_plus_lead.year))==4:
            end_date_plus_lead = end_date_plus_lead.strftime('%Y-%m-%d')

    subsetted_ds = ds['spi'].sel(time=slice(start_date_plus_lead,
                                                 end_date_plus_lead))
    f = subsetted_ds. values.astype(np.float32)
    f[np.isnan(f)] = 0
    ds.close()

    return X,f

def split_data(inpt, outpt, ratios):
    for r in range(len(ratios)):
        rts = ratios[r]
        k = np.random.randint(0,inpt.shape[0],int((rts*inpt.shape[0])))
        if r == 0:
            trainin = inpt[k,:,:,:]
            trainout = outpt[k,:,:]
        elif r == 1:
            valin = inpt[k,:,:,:]
            valout = outpt[k,:,:]
        else:
            testin = inpt[k,:,:,:]
            testout = outpt[k,:,:]
    print(trainin.shape, trainout.shape , valin.shape, valout.shape, testin.shape, testout.shape)
    return trainin, trainout, valin, valout, testin, testout
    

class SPIDataset(Dataset):
    def __init__(self, predictors, predictands):
        self.predictors = predictors
        self.predictands = np.expand_dims(predictands, axis=1)
        assert self.predictors.shape[0] == self.predictands.shape[0], \
                   "The number of predictors must equal the number of predictands!"

    def __len__(self):
        return self.predictors.shape[0]

    def __getitem__(self, idx):
        return self.predictors[idx], self.predictands[idx]
    
def remove_norm(data):
    ds = xr.open_dataset(file_name)
    spi = ds['spi']
    
    data = (data * spi.std(dim='time').values) + spi.mean(dim='time').values
    ds.close()
    return data

# %% [markdown]
# # Create Dataset

# %%
# A. create input/output

num_input_time_steps = 3 
lead_time = 3

climate_model = 'CESM'
algo = 'Net'
train_start_date = '0400-01-01'
train_end_date = '2200-12-16'
# train_end_date = '1978-12-31'

predictors, predictands = assemble_predictors_predictands(train_start_date, train_end_date, lead_time, climate_model, num_input_time_steps, algo)
predictors.shape
# Out:
# Data standardized
# (21609, 3, 13, 20)

# %%
# B. split data 
ratios = [0.64,0.16,0.2]
trainin, trainout, valin, valout, testin, testout = split_data(predictors, predictands, ratios)
# Out:
# (13829, 3, 13, 20) (13829, 13, 20) (3457, 3, 13, 20) (3457, 13, 20) (4321, 3, 13, 20) (4321, 13, 20)

# %%
# C. create dataloader
train_dataset = SPIDataset(trainin, trainout)
val_dataset = SPIDataset(testin, testout)
test_dataset = SPIDataset(testin, testout)

trainloader = DataLoader(train_dataset, batch_size=100)
valloader = DataLoader(val_dataset, batch_size=100)
testloader = DataLoader(test_dataset, batch_size=100)

# %% [markdown]
# ## Setup pretrained CNN

# %%
class CNN(nn.Module):
    def __init__(self, num_input_time_steps=1, print_feature_dimension=False):
        """
        inputs
        -------
            num_input_time_steps        (int) : the number of input time
                                                steps in the predictor
            print_feature_dimension    (bool) : whether or not to print
                                                out the dimension of the features
                                                extracted from the conv layers
        """
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=num_input_time_steps, out_channels=6,  kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12,  kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=12, out_channels=36,  kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(in_channels=36, out_channels=1,  kernel_size=3, padding=1)
        self.print_layer = Print()
        self.print_feature_dimension = print_feature_dimension

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        if self.print_feature_dimension:
            x = self.print_layer(x)
        x = self.conv4(x)
        return x

class Print(nn.Module):
    """
    This class prints out the size of the features
    """
    def forward(self, x):
        print(x.size())
        return x
    
class Identity(torch.nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# %% [markdown]
# ## Network Functions

# %%
def train_network(net, criterion, optimizer, trainloader, valloader, experiment_name, num_epochs=40):
    """
    inputs
    ------

      net               (nn.Module)   : the neural network architecture
      criterion         (nn)          : the loss function (i.e. root mean squared error)
      optimizer         (torch.optim) : the optimizer to use update the neural network 
                                        architecture to minimize the loss function
      trainloader       (torch.utils.data.DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the train dataset
      testloader        (torch.utils.data. DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the test dataset
      experiment_name   Name of the experiment (for visualization purposes)
      num_epochs        Number of epochs (default=40)


    outputs
    -------
      predictions (np.array), and saves the trained neural network as a .pt file
    """
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    net = net.to(device)
    best_loss = np.infty
    train_losses, val_losses = [], []

    for epoch in range(num_epochs):
        for mode, data_loader in [('train', trainloader), ('test', valloader)]:
            #Set the model to train mode to allow its weights to be updated
            #while training
            if mode == 'train':
                net.train()

            #Set the model to eval model to prevent its weights from being updated
            #while testing
            elif mode == 'test':
                net.eval()

            running_loss = 0.0
            for i, data in enumerate(data_loader):
                # get a mini-batch of predictors and predictands
                batch_predictors, batch_predictands = data
                batch_predictands = batch_predictands.to(device)
                batch_predictors = batch_predictors.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                #calculate the predictions of the current neural network
                predictions = net(batch_predictors)

                #quantify the quality of the predictions using a
                #loss function (aka criterion) that is differentiable
                loss = criterion(predictions, batch_predictands)

                if mode == 'train':
                    #the 'backward pass: calculates the gradients of each weight
                    #of the neural network with respect to the loss
                    loss.backward()

                    #the optimizer updates the weights of the neural network
                    #based on the gradients calculated above and the choice
                    #of optimization algorithm
                    optimizer.step()

                #Save the model weights that have the best performance!
                running_loss += loss.item()
                if running_loss < best_loss and mode == 'test':
                    best_loss = running_loss
                    torch.save(net.state_dict(), '{}.pt'.format(experiment_name))
            # print('{} Set: Epoch {:02d}. loss: {:3f}'.format(mode, epoch+1, running_loss/len(data_loader)))
            if mode == 'train':
                train_losses.append(running_loss/len(data_loader))
            else:
                val_losses.append(running_loss/len(data_loader))
    if mode == 'test':
        print('END OF TRAINING: {} Set: Epoch {:02d}. loss: {:3f}'.format(mode, epoch+1, running_loss/len(data_loader)))
    return train_losses, val_losses, net


def test_network(testloader,experiment_name,num_input_time_steps):
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    net = CNN(num_input_time_steps,False)
    net.load_state_dict(torch.load('{}.pt'.format(experiment_name)))
    net.eval()
    net.to(device)

    #the remainder of this notebook calculates the predictions of the best
    #saved model
    for i, data in enumerate(testloader):
        batch_predictors, batch_predictands = data
        batch_predictands = batch_predictands.to(device)
        batch_predictors = batch_predictors.to(device)

        batch_predictions = net(batch_predictors).squeeze()
        batch_predictions = batch_predictions.detach().cpu().numpy()
        try:   
            predictions = np.vstack((predictions, batch_predictions))
        except NameError:
            predictions = batch_predictions
    return predictions


def predict_on_data(data,experiment_name,num_input_time_steps, batch_size):
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    net = CNN(num_input_time_steps,False)
    net.load_state_dict(torch.load('{}.pt'.format(experiment_name)))
    net.eval()
    net.to(device)

    #the remainder of this notebook calculates the predictions of the best
    #saved model
    for i in range(int(np.ceil(data.shape[0]/batch_size))):
        if i == (int(np.ceil(data.shape[0]/batch_size))-1):
            batch_predictors = data[(i*batch_size - 1):(data.shape[0]),:,:,:]
        else:
            batch_predictors = data[i*batch_size:(batch_size - 1),:,:,:]

        batch_predictors = batch_predictors.to(device)

        batch_predictions = net(batch_predictors).squeeze()
        batch_predictions = batch_predictions.detach().cpu().numpy()
        try:   
            predictions = np.vstack((predictions, batch_predictions))
        except NameError:
            predictions = batch_predictions
    return predictions

# %%
num_epochs = 300
net = CNN(num_input_time_steps=num_input_time_steps)
# Calculate number of parameters 
ps = 0
for p in net.parameters(): ps += p.numel()
print('Number of network parameters %s' %ps)
# Train Network
optimizer = optim.Adam(net.parameters(), lr=0.0005)

experiment_name = "threelayerCNN_{}_{}_{}".format(train_start_date, train_end_date,lead_time)
train_losses, val_losses, net = train_network(net, nn.MSELoss(), optimizer, trainloader, valloader, experiment_name, num_epochs)
# Out:
# END OF TRAINING: test Set: Epoch 300. loss: 0.651626

# %% [markdown]
# ## Prediction and Evaluation

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Performance of {} Neural Network During Training'.format(experiment_name))
plt.legend(loc='best')
plt.show()

# %%
# Calculate current MSE
pred = test_network(testloader,experiment_name,num_input_time_steps)
print(pred.shape,testout.shape)
ds = xr.open_dataset(file_name)
spi = ds['spi']
pred_res = remove_norm(pred)
testout_res = remove_norm(testout)
mse = mean_squared_error(pred_res.mean(axis =1).mean(axis = 1), (testout_res).mean(axis =1).mean(axis = 1))


print('MSE:', mse)
# Out:
# (4321, 13, 20) (4321, 13, 20)
# MSE: 0.191241619365727

# %% [markdown]
# ## Test Data Prediction

# %%
import numpy as np
batch_size = 100
test_input = np.load("test_input.npy")

data = torch.as_tensor(np.moveaxis(test_input, 3,1))
predictions = predict_on_data(data,experiment_name,num_input_time_steps, batch_size) 
print(predictions.shape)
np.save("test_submission.npy", predictions)
# Out:
# (120, 13, 20)

# %% [markdown]
# ## Explanation

# %%
# B. GradShap
# !pip install captum
import captum.attr as attr
from captum.attr import visualization as viz
#net is your trained model
gradient_shap = attr.GradientShap(net)

# Defining baseline distribution of images
ds = xr.open_dataset(file_name)
spi = ds['spi']
ref_img_dist = torch.as_tensor(spi.sel(time = slice('1998-09-16','1998-12-16')).values)


pred_label_idx = 0 #in our case this should be 0 since we either predict 1 image/1 pixel
data_loader = testloader
device = "cuda:0" if torch.cuda.is_available() else "cpu"
net = net.to(device)
for i, data in enumerate(data_loader):
    inputs, labels = data
    inputs = inputs[0,None,:,:,:].to(device)
    ref_img_dist = ref_img_dist[None,:,:,:].to(device)
    if i == 0:
        normalized_inp = inputs
        print(inputs.shape)
        print(ref_img_dist.shape)

        attributions_gs = gradient_shap.attribute(normalized_inp,
                                          n_samples=50,
                                          stdevs=0.0001,
                                          baselines=ref_img_dist,
                                          target=pred_label_idx)
        break
        
#Visualization
_ = viz.visualize_image_attr_multiple(np.transpose(attributions_gs.squeeze().cpu().detach().numpy(), (1,2,0)),
                             np.transpose(normalized_inp.squeeze().cpu().detach().numpy(), (1,2,0)),
                             methods=["original_image", "heat_map"],
                             signs=['all', 'positive'],
                             cmap=default_cmap,
                             show_colorbar=True)
